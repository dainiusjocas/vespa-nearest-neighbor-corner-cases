# %%
# The goal is to learn how to get either the first or the second phase relevance score in the global phase without recalculating second-phase unnecessary.

# %%
# !docker run --detach --rm --name vespa-globalrank --hostname vespa-globalrank --publish 0.0.0.0:8080:8080 --publish 0.0.0.0:19050:19050 --publish 0.0.0.0:19071:19071 vespaengine/vespa:8.551.21
# Out:
# d40856f418cdb8a79ac49f6fe8b903e256efd339b733a4af66f6a0efa59ad4f2

# %%
# Out:
# 9f09841922f316bfc6ad3311163407018b6bc00f144dabd5e8750716161813c1

# %%
# Setup a simple Vespa application package
from vespa.package import (ApplicationPackage, Field, Schema, Document, RankProfile, Function,
                           QueryProfile, QueryProfileType, FirstPhaseRanking, GlobalPhaseRanking, SecondPhaseRanking,)
from vespa.io import VespaResponse

vap = ApplicationPackage(
    name="globalrelevance",
    query_profile_type=QueryProfileType(
        fields=[]
    ),
    query_profile=QueryProfile(
        fields=[]
    ),
    schema=[
        Schema(
            name="doc",
            document=Document(
                fields=[
                    Field(
                        name="id",
                        type="int",
                        indexing=["attribute"],
                        attribute=["fast-search"],
                    ),
                ]
            ),
            rank_profiles=[
                RankProfile(
                    name="global_1",
                    first_phase=FirstPhaseRanking(
                        expression='1',
                    ),
                    global_phase=GlobalPhaseRanking(
                        expression='firstPhase',
                        rerank_count=10,
                    ),
                    match_features=['firstPhase', 'firstPhaseRank'],
                    summary_features=['firstPhase'],
                ),
                RankProfile(
                    name="global_2",
                    first_phase=FirstPhaseRanking(
                        expression='2',
                    ),
                    global_phase=GlobalPhaseRanking(
                        expression='firstPhase',
                        rerank_count=10,
                    ),
                    match_features=['firstPhase', 'firstPhaseRank'],
                    summary_features=['firstPhase'],
                ),
                RankProfile(
                    name="global_3",
                    functions=[
                        Function(
                            name='sp',
                            args=['fprank'],
                            expression='if(fprank < 10000, fprank * 100000, firstPhase / 10000)'
                        ),
                        Function(
                            name='expensive_function',
                            # args=['first_phase_rank'],
                            expression='firstPhaseRank * 10', # let's pretend that here we are calling a neural net
                        ),
                        Function(
                            name='sp2',
                            args=[],
                            expression='if(firstPhaseRank < 10000, expensive_function, firstPhase - 50)'
                        )
                    ],
                    first_phase=FirstPhaseRanking(
                        expression='attribute(id)',
                    ),
                    second_phase=SecondPhaseRanking(
                        expression='sp2',
                        rerank_count=3,
                    ),
                    global_phase=GlobalPhaseRanking(
                        expression='secondPhase',
                        rerank_count=5,
                    ),
                    match_features=['firstPhase', 'firstPhaseRank', 'secondPhase'],
                ),
            ]
        )
    ]
)

# %%
vap_file_name = "global-relevance.zip"
vap.to_zipfile(vap_file_name)
! vespa deploy {vap_file_name} -t http://localhost:19071
# Out:
# Uploading application package... done;1m⣟
# Success: Deployed 'global-relevance.zip' with session ID 9

# %%
from vespa.application import Vespa

prod_vespa_host = "http://localhost"
app = Vespa(url=prod_vespa_host, port=8080)

# %%
# Create and feed 5 docs
docs = [
    {
        'id': f'{i}',
        'fields': {
            'id': i
        }
    } for i in range(10)]


def callback(response: VespaResponse, document_id: str):
    if not response.is_successful():
        print(f"Error when feeding document {document_id}: {response.get_json()}")


app.feed_iterable(docs, schema="doc", namespace="doc", callback=callback, max_connections=12, )

# %%
app.query(body={
    'yql': 'select * '
           'from sources * '
           'where true',
    'ranking.profile': 'global_3',
}).json
# Out:
# {'root': {'id': 'toplevel',
#   'relevance': 1.0,
#   'fields': {'totalCount': 10},
#   'coverage': {'coverage': 100,
#    'documents': 10,
#    'full': True,
#    'nodes': 1,
#    'results': 1,
#    'resultsFull': 1},
#   'children': [{'id': 'id:doc:doc::7',
#     'relevance': 30.0,
#     'source': 'globalrelevance_content',
#     'fields': {'matchfeatures': {'firstPhase': 7.0,
#       'firstPhaseRank': 3.0,
#       'secondPhase': 30.0},
#      'sddocname': 'doc',
#      'documentid': 'id:doc:doc::7'}},
#    {'id': 'id:doc:doc::8',
#     'relevance': 20.0,
#     'source': 'globalrelevance_content',
#     'fields': {'matchfeatures': {'firstPhase': 8.0,
#       'firstPhaseRank': 2.0,
#       'secondPhase': 20.0},
#      'sddocname': 'doc',
#      'documentid': 'id:doc:doc::8'}},
#    {'id': 'id:doc:doc::9',
#     'relevance': 10.0,
#     'source': 'globalrelevance_content',
#     'fields': {'matchfeatures': {'firstPhase': 9.0,
#       'firstPhaseRank': 1.0,
#       'secondPhase': 10.0},
#      'sddocname': 'doc',
#      'documentid': 'id:doc:doc::9'}},
#    {'id': 'id:doc:doc::6',
#     'relevance': -44.0,
#     'source': 'globalrelevance_content',
#     'fields': {'matchfeatures': {'firstPhase': 6.0,
#       'firstPhaseRank': 1.7976931348623157e+308,
#       'secondPhase': -44.0},
#      'sddocname': 'doc',
#      'documentid': 'id:doc:doc::6'}},
#    {'id': 'id:doc:doc::5',
#     'relevance': -45.0,
#     'source': 'globalrelevance_content',
#     'fields': {'matchfeatures': {'firstPhase': 5.0,
#       'firstPhaseRank': 1.7976931348623157e+308,
#       'secondPhase': -45.0},
#      'sddocname': 'doc',
#      'documentid': 'id:doc:doc::5'}},
#    {'id': 'id:doc:doc::4',
#     'relevance': -48.0,
#     'source': 'globalrelevance_content',
#     'fields': {'matchfeatures': {'firstPhase': 4.0,
#       'firstPhaseRank': 1.7976931348623157e+308,
#       'secondPhase': -46.0},
#      'sddocname': 'doc',
#      'documentid': 'id:doc:doc::4'}},
#    {'id': 'id:doc:doc::3',
#     'relevance': -51.0,
#     'source': 'globalrelevance_content',
#     'fields': {'matchfeatures': {'firstPhase': 3.0,
#       'firstPhaseRank': 1.7976931348623157e+308,
#       'secondPhase': -47.0},
#      'sddocname': 'doc',
#      'documentid': 'id:doc:doc::3'}},
#    {'id': 'id:doc:doc::2',
#     'relevance': -54.0,
#     'source': 'globalrelevance_content',
#     'fields': {'matchfeatures': {'firstPhase': 2.0,
#       'firstPhaseRank': 1.7976931348623157e+308,
#       'secondPhase': -48.0},
#      'sddocname': 'doc',
#      'documentid': 'id:doc:doc::2'}},
#    {'id': 'id:doc:doc::1',
#     'relevance': -57.0,
#     'source': 'globalrelevance_content',
#     'fields': {'matchfeatures': {'firstPhase': 1.0,
#       'firstPhaseRank': 1.7976931348623157e+308,
#       'secondPhase': -49.0},
#      'sddocname': 'doc',
#      'documentid': 'id:doc:doc::1'}},
#    {'id': 'id:doc:doc::0',
#     'relevance': -60.0,
#     'source': 'globalrelevance_content',
#     'fields': {'matchfeatures': {'firstPhase': 0.0,
#       'firstPhaseRank': 1.7976931348623157e+308,
#       'secondPhase': -50.0},
#      'sddocname': 'doc',
#      'documentid': 'id:doc:doc::0'}}]}}

# %%
# The above results are good, because only the first 3 hits have relevance score >3. The trace doesn't indicate that the second phase was calculated.

# %%
app.query(body={
    'yql': 'select * '
           'from sources * '
           'where true',
    'ranking.profile': 'global_3',
    # 'ranking.globalPhase.rerankCount': 0,
    'trace.level': 4,
}).json
# Out:
# {'trace': {'children': [{'message': "Using query profile 'default' of type 'root'"},
#    {'message': 'Resolved properties:\n'},
#    {'message': "Invoking chain 'vespa' [com.yahoo.prelude.statistics.StatisticsSearcher@native -> com.yahoo.prelude.querytransform.PhrasingSearcher@vespa -> ... -> federation@native]"},
#    {'children': [{'message': "Invoke searcher 'com.yahoo.prelude.statistics.StatisticsSearcher in native'"},
#      {'message': "Invoke searcher 'com.yahoo.prelude.querytransform.PhrasingSearcher in vespa'"},
#      {'message': "Invoke searcher 'com.yahoo.prelude.searcher.FieldCollapsingSearcher in vespa'"},
#      {'message': "Invoke searcher 'com.yahoo.search.yql.MinimalQueryInserter in vespa'"},
#      {'message': 'YQL query parsed: [select * from sources * where true]'},
#      {'message': "Invoke searcher 'com.yahoo.search.yql.FieldFilter in vespa'"},
#      {'message': "Invoke searcher 'com.yahoo.prelude.searcher.JuniperSearcher in vespa'"},
#      {'message': "Invoke searcher 'com.yahoo.prelude.searcher.PosSearcher in vespa'"},
#      {'message': "Invoke searcher 'com.yahoo.prelude.semantics.SemanticSearcher in vespa'"},
#      {'message': "Invoke searcher 'com.yahoo.search.grouping.GroupingQueryParser in vespa'"},
#      {'message': "Invoke searcher 'com.yahoo.prelude.searcher.BlendingSearcher in vespa'"},
#      {'message': "Invoke searcher 'com.yahoo.search.querytransform.WeakAndReplacementSearcher in vespa'"},
#      {'message': "Invoke searcher 'com.yahoo.search.searchers.OpportunisticWeakAndSearcher in vespa'"},
#      {'message': "Invoke searcher 'federation in native'"},
#      {'message': 'Federating to [globalrelevance_content]'},
#      {'children': [{'message': "Invoke searcher 'com.yahoo.search.querytransform.NGramSearcher in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.search.querytransform.DefaultPositionSearcher in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.prelude.querytransform.CJKSearcher in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.prelude.querytransform.LiteralBoostSearcher in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.search.querytransform.RangeQueryOptimizer in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.search.querytransform.SortingDegrader in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.search.searchers.QueryValidator in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.search.grouping.GroupingValidator in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.search.querytransform.WandSearcher in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.prelude.querytransform.RecallSearcher in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.search.searchers.ValidateNearestNeighborSearcher in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.search.searchers.ValidateMatchPhaseSearcher in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.search.searchers.ValidateFuzzySearcher in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.search.yql.FieldFiller in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.search.searchers.InputCheckingSearcher in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.search.significance.SignificanceSearcher in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.prelude.querytransform.StemmingSearcher in globalrelevance_content'"},
#        {'message': 'Stemming with language ENGLISH using OpenNlpLinguistics'},
#        {'message': 'Stemming: [select * from sources * where true timeout 487]'},
#        {'message': "Invoke searcher 'com.yahoo.prelude.querytransform.NormalizingSearcher in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.search.querytransform.VespaLowercasingSearcher in globalrelevance_content'"},
#        {'message': 'Lowercasing: [select * from sources * where true timeout 487]'},
#        {'message': "Invoke searcher 'com.yahoo.prelude.searcher.ValidateSortingSearcher in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.search.querytransform.BooleanSearcher in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.search.grouping.vespa.GroupingExecutor in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.prelude.searcher.ValidatePredicateSearcher in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.search.searchers.ContainerLatencySearcher in globalrelevance_content'"},
#        {'message': "Invoke searcher 'com.yahoo.prelude.cluster.ClusterSearcher in globalrelevance_content'"},
#        {'message': 'globalrelevance_content.num0 search to dispatch: query=[TRUE] timeout=487ms offset=0 hits=10 rankprofile[global_3] groupingSessionCache=true sessionId=1f5f37a0-8721-4279-91ae-e1c8b42dabfe.1753818846502.20.global_3 grouping=0 :  restrict=[doc]'},
#        {'message': 'Current state of query tree: TRUE'},
#        {'message': 'YQL+ representation: select * from sources * where true timeout 487'},
#        {'message': 'Dispatching to search node in cluster = dispatcher.globalrelevance_content key = 0 hostname = vespa-randrank path = 0 in group 0 statusIsKnown = true working = true activeDocs = 100000 targetActiveDocs = 100000'},
#        {'message': [{'start_time': '2025-07-29 19:54:06.504 UTC',
#           'traces': [{'timestamp_ms': 0.499443,
#             'event': 'searching for 10 hits at offset 0',
#             'tag': 'query_start'},
#            {'traces': [{'timestamp_ms': 0.686624,
#               'event': 'Start query setup'},
#              {'timestamp_ms': 0.825698,
#               'event': 'Perform dictionary lookups and posting lists initialization'},
#              {'timestamp_ms': 0.974186, 'event': 'Complete query setup'}],
#             'timestamp_ms': 0.974894,
#             'tag': 'query_setup'},
#            {'timestamp_ms': 14.666468,
#             'tag': 'query_execution',
#             'threads': [{'traces': [{'timestamp_ms': 1.049158,
#                 'event': 'Start MatchThread::run'},
#                {'timestamp_ms': 1.216055,
#                 'event': 'Start match and first phase rank'},
#                {'timestamp_ms': 13.620142,
#                 'event': 'Start second phase rerank'},
#                {'timestamp_ms': 14.001253, 'event': 'Create result set'},
#                {'timestamp_ms': 14.617277, 'event': 'Start thread merge'},
#                {'timestamp_ms': 14.618069,
#                 'event': 'MatchThread::run Done'}]}]},
#            {'timestamp_ms': 14.696706,
#             'event': 'returning 10 hits from total 100000',
#             'tag': 'query_reply'}],
#           'distribution-key': 0,
#           'document-type': 'doc',
#           'duration_ms': 14.698497}]},
#        {'message': 'globalrelevance_content.num0 dispatch response: Result (10 of total 100000 hits)'},
#        {'message': 'Use global-phase from [doc] to re-rank 5 hits'},
#        {'message': "Return searcher 'com.yahoo.prelude.cluster.ClusterSearcher in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.search.searchers.ContainerLatencySearcher in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.prelude.searcher.ValidatePredicateSearcher in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.search.grouping.vespa.GroupingExecutor in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.search.querytransform.BooleanSearcher in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.prelude.searcher.ValidateSortingSearcher in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.search.querytransform.VespaLowercasingSearcher in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.prelude.querytransform.NormalizingSearcher in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.prelude.querytransform.StemmingSearcher in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.search.significance.SignificanceSearcher in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.search.searchers.InputCheckingSearcher in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.search.yql.FieldFiller in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.search.searchers.ValidateFuzzySearcher in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.search.searchers.ValidateMatchPhaseSearcher in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.search.searchers.ValidateNearestNeighborSearcher in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.prelude.querytransform.RecallSearcher in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.search.querytransform.WandSearcher in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.search.grouping.GroupingValidator in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.search.searchers.QueryValidator in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.search.querytransform.SortingDegrader in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.search.querytransform.RangeQueryOptimizer in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.prelude.querytransform.LiteralBoostSearcher in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.prelude.querytransform.CJKSearcher in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.search.querytransform.DefaultPositionSearcher in globalrelevance_content'"},
#        {'message': "Return searcher 'com.yahoo.search.querytransform.NGramSearcher in globalrelevance_content'"},
#        {'message': 'GroupingExecutor.fill([presentation]) = {[[presentation]]}'},
#        {'message': "globalrelevance_content.num0 fill to dispatch: query=[TRUE] timeout=487ms offset=0 hits=10 rankprofile[global_3] groupingSessionCache=true sessionId=1f5f37a0-8721-4279-91ae-e1c8b42dabfe.1753818846502.20.global_3 grouping=0 :  restrict=[doc] summary='[presentation]'"},
#        {'message': 'Current state of query tree: TRUE'},
#        {'message': 'YQL+ representation: select * from sources * where true timeout 487'},
#        {'message': 'ProtoBuf: Resending query during document summary fetching'}]},
#      {'message': 'Got 10 hits from source:globalrelevance_content'},
#      {'message': "Return searcher 'federation in native'"},
#      {'message': "Return searcher 'com.yahoo.search.searchers.OpportunisticWeakAndSearcher in vespa'"},
#      {'message': "Return searcher 'com.yahoo.search.querytransform.WeakAndReplacementSearcher in vespa'"},
#      {'message': "Return searcher 'com.yahoo.prelude.searcher.BlendingSearcher in vespa'"},
#      {'message': "Return searcher 'com.yahoo.search.grouping.GroupingQueryParser in vespa'"},
#      {'message': "Return searcher 'com.yahoo.prelude.semantics.SemanticSearcher in vespa'"},
#      {'message': "Return searcher 'com.yahoo.prelude.searcher.PosSearcher in vespa'"},
#      {'message': "Return searcher 'com.yahoo.prelude.searcher.JuniperSearcher in vespa'"},
#      {'message': "Return searcher 'com.yahoo.search.yql.FieldFilter in vespa'"},
#      {'message': "Return searcher 'com.yahoo.search.yql.MinimalQueryInserter in vespa'"},
#      {'message': "Return searcher 'com.yahoo.prelude.searcher.FieldCollapsingSearcher in vespa'"},
#      {'message': "Return searcher 'com.yahoo.prelude.querytransform.PhrasingSearcher in vespa'"},
#      {'message': "Return searcher 'com.yahoo.prelude.statistics.StatisticsSearcher in native'"},
#      {'message': "Query time query 'TRUE': 24 ms"},
#      {'message': "Summary fetch time query 'TRUE': 2 ms"},
#      {'message': 'Vespa version: 8.551.21'}]}]},
#  'root': {'id': 'toplevel',
#   'relevance': 1.0,
#   'fields': {'totalCount': 100000},
#   'coverage': {'coverage': 100,
#    'documents': 100000,
#    'full': True,
#    'nodes': 1,
#    'results': 1,
#    'resultsFull': 1},
#   'children': [{'id': 'id:doc:doc::99998',
#     'relevance': 1753818846.0,
#     'source': 'globalrelevance_content',
#     'fields': {'matchfeatures': {'firstPhase': 9999800000000.0,
#       'firstPhaseRank': 2.0,
#       'secondPhase': 1753818846.0},
#      'sddocname': 'doc',
#      'documentid': 'id:doc:doc::99998',
#      'summaryfeatures': {'firstPhase': 9999800000000.0,
#       'vespa.summaryFeatures.cached': 0.0}}},
#    {'id': 'id:doc:doc::99999',
#     'relevance': 1753818846.0,
#     'source': 'globalrelevance_content',
#     'fields': {'matchfeatures': {'firstPhase': 9999900000000.0,
#       'firstPhaseRank': 1.0,
#       'secondPhase': 1753818846.0},
#      'sddocname': 'doc',
#      'documentid': 'id:doc:doc::99999',
#      'summaryfeatures': {'firstPhase': 9999900000000.0,
#       'vespa.summaryFeatures.cached': 0.0}}},
#    {'id': 'id:doc:doc::99997',
#     'relevance': 1753818846.0,
#     'source': 'globalrelevance_content',
#     'fields': {'matchfeatures': {'firstPhase': 9999700000000.0,
#       'firstPhaseRank': 3.0,
#       'secondPhase': 1753818846.0},
#      'sddocname': 'doc',
#      'documentid': 'id:doc:doc::99997',
#      'summaryfeatures': {'firstPhase': 9999700000000.0,
#       'vespa.summaryFeatures.cached': 0.0}}},
#    {'id': 'id:doc:doc::99996',
#     'relevance': 1753818846.0,
#     'source': 'globalrelevance_content',
#     'fields': {'matchfeatures': {'firstPhase': 9999600000000.0,
#       'firstPhaseRank': 1.7976931348623157e+308,
#       'secondPhase': 1753818846.0},
#      'sddocname': 'doc',
#      'documentid': 'id:doc:doc::99996',
#      'summaryfeatures': {'firstPhase': 9999600000000.0,
#       'vespa.summaryFeatures.cached': 0.0}}},
#    {'id': 'id:doc:doc::99995',
#     'relevance': 1753818846.0,
#     'source': 'globalrelevance_content',
#     'fields': {'matchfeatures': {'firstPhase': 9999500000000.0,
#       'firstPhaseRank': 1.7976931348623157e+308,
#       'secondPhase': 1753818846.0},
#      'sddocname': 'doc',
#      'documentid': 'id:doc:doc::99995',
#      'summaryfeatures': {'firstPhase': 9999500000000.0,
#       'vespa.summaryFeatures.cached': 0.0}}},
#    {'id': 'id:doc:doc::99994',
#     'relevance': 1753818844.5,
#     'source': 'globalrelevance_content',
#     'fields': {'matchfeatures': {'firstPhase': 9999400000000.0,
#       'firstPhaseRank': 1.7976931348623157e+308,
#       'secondPhase': 1753818846.0},
#      'sddocname': 'doc',
#      'documentid': 'id:doc:doc::99994',
#      'summaryfeatures': {'firstPhase': 9999400000000.0,
#       'vespa.summaryFeatures.cached': 0.0}}},
#    {'id': 'id:doc:doc::99993',
#     'relevance': 1753818844.0,
#     'source': 'globalrelevance_content',
#     'fields': {'matchfeatures': {'firstPhase': 9999300000000.0,
#       'firstPhaseRank': 1.7976931348623157e+308,
#       'secondPhase': 1753818846.0},
#      'sddocname': 'doc',
#      'documentid': 'id:doc:doc::99993',
#      'summaryfeatures': {'firstPhase': 9999300000000.0,
#       'vespa.summaryFeatures.cached': 0.0}}},
#    {'id': 'id:doc:doc::99992',
#     'relevance': 1753818843.5,
#     'source': 'globalrelevance_content',
#     'fields': {'matchfeatures': {'firstPhase': 9999200000000.0,
#       'firstPhaseRank': 1.7976931348623157e+308,
#       'secondPhase': 1753818846.0},
#      'sddocname': 'doc',
#      'documentid': 'id:doc:doc::99992',
#      'summaryfeatures': {'firstPhase': 9999200000000.0,
#       'vespa.summaryFeatures.cached': 0.0}}},
#    {'id': 'id:doc:doc::99991',
#     'relevance': 1753818843.0,
#     'source': 'globalrelevance_content',
#     'fields': {'matchfeatures': {'firstPhase': 9999100000000.0,
#       'firstPhaseRank': 1.7976931348623157e+308,
#       'secondPhase': 1753818846.0},
#      'sddocname': 'doc',
#      'documentid': 'id:doc:doc::99991',
#      'summaryfeatures': {'firstPhase': 9999100000000.0,
#       'vespa.summaryFeatures.cached': 0.0}}},
#    {'id': 'id:doc:doc::99990',
#     'relevance': 1753818842.5,
#     'source': 'globalrelevance_content',
#     'fields': {'matchfeatures': {'firstPhase': 9999000000000.0,
#       'firstPhaseRank': 1.7976931348623157e+308,
#       'secondPhase': 1753818846.0},
#      'sddocname': 'doc',
#      'documentid': 'id:doc:doc::99990',
#      'summaryfeatures': {'firstPhase': 9999000000000.0,
#       'vespa.summaryFeatures.cached': 0.0}}}]}}

# %%
# learnings:
# 1. first phase rank is the rank before the second phase
# 2. if the global phase reranks more (N) than a second phase (M) hits, the second phase score is calculated for N hits, probably at different times (2nd phase and fill() phase)
# 3. There is no `currentRelevance` score, which is as of this moment.

# %%
# !docker stop vespa-globalrank
# Out:
# vespa-randrank
