# %%
# The goal is to demonstrate how to use the new `relevanceScore` available only in the `global-phase`.

# %%
# !docker run --detach --rm --name vespa-globalrank-2 --hostname vespa-globalrank-2 --publish 0.0.0.0:8080:8080 --publish 0.0.0.0:19050:19050 --publish 0.0.0.0:19071:19071 vespaengine/vespa:8.559.30
# Out:
# Unable to find image 'vespaengine/vespa:8.559.30' locally
# 8.559.30: Pulling from vespaengine/vespa
#
# 4a177d9f: Already exists
# a556b7c0: Pulling fs layer
# 490b02d6: Pulling fs layer
# 239e1edb: Pulling fs layer
# Digest: sha256:dc4fdac411eb2b60f1691e4a5e30080d8c08923f200d87d5b8812defa14ba70e[4ADownloading  17.22MB/568.8MBDownloading  31.21MB/568.8MBDownloading  102.2MB/568.8MBDownloading  106.5MB/568.8MBDownloading  226.6MB/568.8MBDownloading  262.1MB/568.8MBDownloading  297.6MB/568.8MBDownloading  458.4MB/568.8MBDownloading    495MB/568.8MBDownloading  518.2MB/568.8MBDownloading  531.7MB/568.8MBDownloading  532.8MB/568.8MBDownloading  538.1MB/568.8MBDownloading  555.9MB/568.8MBDownloading  562.9MB/568.8MB
# Status: Downloaded newer image for vespaengine/vespa:8.559.30
# 2dd8ae509985b4992b7862e70132326044830941ea8c2cfbc1be28d057c0f902

# %%
# !docker stop vespa-globalrank-2
# Out:
# vespa-globalrank-2
